# %%
# %run  "./env_setup.py"
# Out:
# User:  nchitiwong
# Database:  postgresql://nchitiwong:secret@ads1.datasci.vt.edu:5432/ads_db1

# %%
# %%sql
# --
# -- Here's a simple test SQL
# --
# select *
# from dw1.customer
# limit 5;
# Out:
#  * postgresql://nchitiwong:***@ads1.datasci.vt.edu:5432/ads_db1
# 5 rows affected.
# [(1, 'Kathryn', 'Cooper', '80701'),
#  (2, 'Edward', 'Adams', '80425'),
#  (3, 'Rebecca', 'Chapman', '80751'),
#  (4, 'Dana', 'Wolf', '80820'),
#  (5, 'David', 'Dalton', '80515')]

# %%
# %%sql
# drop table if exists {username}.campaign;
# Out:
#  * postgresql://nchitiwong:***@ads1.datasci.vt.edu:5432/ads_db1
# Done.
# []

# %%
# %%sql
# create table {username}.campaign as
# select * from dw1.campaign;
# Out:
#  * postgresql://nchitiwong:***@ads1.datasci.vt.edu:5432/ads_db1
# 2000 rows affected.
# []

# %%
# %%sql
# drop table if exists {username}.customer;
# Out:
#  * postgresql://nchitiwong:***@ads1.datasci.vt.edu:5432/ads_db1
# Done.
# []

# %%
# %%sql
# create table {username}.customer as
# select * from dw1.customer;
# Out:
#  * postgresql://nchitiwong:***@ads1.datasci.vt.edu:5432/ads_db1
# 5000 rows affected.
# []

# %%
# %%sql
# drop table if exists {username}.product;
# Out:
#  * postgresql://nchitiwong:***@ads1.datasci.vt.edu:5432/ads_db1
# Done.
# []

# %%
# %%sql
# create table {username}.product as
# select * from dw1.product;
# Out:
#  * postgresql://nchitiwong:***@ads1.datasci.vt.edu:5432/ads_db1
# 500 rows affected.
# []

# %%
# %%sql
# drop table if exists {username}.store;
# Out:
#  * postgresql://nchitiwong:***@ads1.datasci.vt.edu:5432/ads_db1
# Done.
# []

# %%
# %%sql
# create table {username}.store as
# select * from dw1.store;
# Out:
#  * postgresql://nchitiwong:***@ads1.datasci.vt.edu:5432/ads_db1
# 10 rows affected.
# []

# %%
# %%sql
# drop table if exists {username}.transaction_pos;
# Out:
#  * postgresql://nchitiwong:***@ads1.datasci.vt.edu:5432/ads_db1
# Done.
# []

# %%
# %%sql
# create table {username}.transaction_pos as
# select * from dw1.transaction_pos;
# Out:
#  * postgresql://nchitiwong:***@ads1.datasci.vt.edu:5432/ads_db1
# 619738 rows affected.
# []

# %%
# %%sql
# drop table if exists {username}.zip;
# Out:
#  * postgresql://nchitiwong:***@ads1.datasci.vt.edu:5432/ads_db1
# Done.
# []

# %%
# %%sql
# create table {username}.zip as
# select * from dw1.zip;
# Out:
#  * postgresql://nchitiwong:***@ads1.datasci.vt.edu:5432/ads_db1
# 72 rows affected.
# []

# %%
# %%sql
# drop table if exists {username}.zip_demographics_decile;
# Out:
#  * postgresql://nchitiwong:***@ads1.datasci.vt.edu:5432/ads_db1
# Done.
# []

# %%
# %%sql
# create table {username}.zip_demographics_decile as
# select * from dw1.zip_demographics_decile;
# Out:
#  * postgresql://nchitiwong:***@ads1.datasci.vt.edu:5432/ads_db1
# 72 rows affected.
# []
